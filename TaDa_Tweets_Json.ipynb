# %%
import os
import time

os.chdir("/Users/ishitagopal/Box/twitter_data/unverified_NA_accounts")
os.getcwd()

# %%
import tweepy 
import csv
import json

#Twitter API credentials -- input required 
consumer_key=""
consumer_secret=""
access_key=""
access_secret=""


def get_all_tweets(screen_name):
    #Twitter only allows access to a users most recent 3240 tweets with this method

    #authorize twitter, initialize tweepy
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_key, access_secret)
    api = tweepy.API(auth)

    #initialize a list to hold all the tweepy Tweets
    alltweets = []

    #make initial request for most recent tweets (200 is the maximum allowed count)
    new_tweets = api.user_timeline(screen_name = screen_name,count=200, exclude_replies=False,tweet_mode="extended")

    #save most recent tweets
    alltweets.extend(new_tweets)

    #save the id of the oldest tweet less one
    oldest = alltweets[-1].id - 1

    #keep grabbing tweets until there are no tweets left to grab
    while len(new_tweets) > 0:
        print ("getting tweets before %s" % (oldest))
        
         #all subsiquent requests use the max_id param to prevent duplicates

        new_tweets = api.user_timeline(screen_name = screen_name,count=200,max_id=oldest, exclude_replies=False,
                                       tweet_mode="extended")
        
        #save most recent tweets
        
        alltweets.extend(new_tweets)
        
        #update the id of the oldest tweet less one
        
        oldest = alltweets[-1].id - 1
        
        print ("...%s tweets downloaded so far" % (len(alltweets)))
        
        #transform the tweepy tweets into a 2D array that will populate the csv	
#    outtweets = [[tweet.id_str,
#                  tweet.created_at, 
#                  tweet.text.encode("utf-8"),
#                  tweet.text,
#                  tweet.user.screen_name,
#                  tweet.entities.get('hashtags',""),
#                  tweet.retweet_count,
#                  tweet.favorite_count,
#                  tweet.entities.get('user_mentions',''),
#                  tweet.source,
#                  tweet.user.location.encode("utf-8"),
#                  len(tweet.entities.get('user_mentions','')),
#                  tweet.entities.get('urls',''),
#                  tweet.entities.get("media",'')] 
#                 
#                 for tweet in alltweets]
    
#write the csv
#    with open('%s_tweets.csv' % screen_name, 'w',encoding='utf-8') as f:
#        writer = csv.writer(f)
#        writer.writerow(["tweet_id",
#                        "created_at",    #UTC
#                         "encoded_text",
#                         "text",
#                         "screen_name",
#                         "hashtags_count",
#                         "retweet_count",
#                         "favorite_count",
#                         "mentions",
#                         "source",
#                         "location",
#                         "count_others_mentioned",
#                         "count_urls",
#                         "media", 
#                         "tweet_lang"])
#        
#        writer.writerows(outtweets)

    
    with open('%s_tweets.json' % screen_name, 'w', encoding='utf8') as file:
        json.dump([tweet._json for tweet in alltweets], file)
        
    print("writen to file")

# %%
assembly_handles =['AmeliaBelisario',
 'AmericoDeGrazia',
 'ArmandoArmas',
 'DipMarquina',
 'DipMelvaParedes',
 'FreddyGuevaraC',
 'JuanPGuanipa',
 'JuanPabloGve',
 'JuanRequesens',
 'JulioBorges',
 'LuisFlorido',
 'MBMartinezR',
 'MariMagallanesC',
 'MariaGMonagas',
 'Miguel_Pizarro',
 'Milagrovalerom',
 'RichardBlancoOf',
 'SuarezBolivia',
 'TomasGuanipa',
 'bozotamayo',
 'delsasolorzano',
 'edgarzambranoad',
 'fcosucre',
 'gabyarellanoVE',
 'hramosallup',
 'ismaelprogreso',
 'jguaido',
 'jonyrahal',
 'joseolivaresm',
 'stalin_gonzalez',
 'williamsdavila']

# %%
for item in assembly_handles:
     get_all_tweets(item)
     time.sleep(30)
